# %% [markdown]
# MÔ HÌNH BAYES
#
# NAIVE BAYES

# %% [markdown]
# Định lý Bayes:
#
# P(A/B) = [P(B/A)*P(A)]/P(B)

# %% [markdown]
# Xây dựng mô hình lọc thư rác

# %%
import numpy as np
import matplotlib.pyplot as pl
import math
import pandas as pd
import random
import re
from collections import defaultdict

# %%
def get_data(path):
    data = []
    is_spam = 'spam'
    with open(path, 'r') as file:
        for line in file:
            if line.startswith('ham'):
                # nếu sms không phải là sms rác
                data.append((line[3:], 0)

            # lấy từ ký tự thứ 4 (3 ký tự đầu là : 'ham')
            else: # nếu sms là sms rác
                data.append((line[4:], 1))
            # lays
