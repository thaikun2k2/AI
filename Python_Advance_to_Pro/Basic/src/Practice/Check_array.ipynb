# %% [markdown]
# cho 1 mảng cho trc kiểm tra xem có phải là mảng tăng dần hay không
#
# eg:
# input: [1, 2, 3, 4, 5]
# output: True
#
#
# input: [1, 3, 2, 4, 5]
# output: False

# %% [markdown]
# Monotonic là đãy đơn điệu

# %%
arr1 = [1, 2, 3, 4, 5]
arr2 = [1, 3, 2, 4, 5]

def check_arrays(arrr):
    for i in range(len(arrr) - 1):
        if arrr[i] > arrr[i + 1]:
            return False
    return True

print(check_arrays(arr1))  # Output: True

print(check_arrays(arr2))  # Output: False
# Out:
# True
# False

# %%
arr1 = [1, 2, 3, 4, 5]
arr2 = [1, 3, 2, 4, 5]
arr3 = [5, 4, 3, 2, 1]

daytang = False
daygiam = False

#arr =arr1
arr =arr2
#arr = arr3
daytang = all(arr[i] < arr[i + 1] for i in range(len(arr) - 1))
daygiam = all(arr[i] > arr[i + 1] for i in range(len(arr) - 1))

if daytang:
    print("Mảng tăng dần.")
if daygiam:
    print("Mảng giảm dần.")
if ((daytang == False) and (daygiam == False)):
    print("Mảng ko tăng ko giảm.")
# Out:
# Mảng ko tăng ko giảm.

# %%
arr1 = [1, 2, 3, 4, 5]
arr2 = [1, 3, 2, 4, 5]
arr3 = [5, 4, 3, 2, 1]

daytang = False
daygiam = False

arr = arr3
if arr[0] < arr[1]:
   daytang = True
   for i in range(len(arr) - 1):
        if arr[i] >= arr[i + 1]:
            daytang = False
if arr[0] > arr[1]:
    daygiam = True
    for i in range(len(arr) - 1):
        if arr[i] <= arr[i + 1]:
            daygiam = False
if daytang:
    print("Mảng tăng dần.")
if daygiam:
    print("Mảng giảm dần.")

if daytang == False and daygiam == False:
    print("Mảng ko tăng ko giảm.")
# Out:
# Mảng giảm dần.

# %%
arr1 = [1, 2, 3, 4, 5]
arr2 = [1, 3, 2, 4, 5]
arr3 = [5, 4, 3, 2, 1]

ds = [arr1, arr2, arr3]

#arr =arr1
#arr =arr2
arr = arr3


def check_arrays(arr):
    if all(arr[i] < arr[i + 1] for i in range(len(arr) - 1)):
        return "Mảng tăng dần."
    elif all(arr[i] > arr[i + 1] for i in range(len(arr) - 1)):
        return "Mảng giảm dần."
    else:
        return "Mảng ko tăng ko giảm."

# for i in ds:
#     print(check_arrays(i))


for i, arr in enumerate(ds, 1):
    print(f"Mảng {i}: {check_arrays(arr)}")
# Out:
# Mảng 1: Mảng tăng dần.
# Mảng 2: Mảng ko tăng ko giảm.
# Mảng 3: Mảng giảm dần.
