# %% [markdown]
# Array giống list nhưng linh hoạt và hiệu quả hơn.
#
# Library Numpy là 1 thư viện hỗ trợ cho vs tính toán về mảng dữ liệu. có chứa các đối tượng mảng đa chiều và công cụ để làm việc với chúng.
# ALL các array object đều thuộc type: ndarray
